# %% [markdown]
# # Spotipy Tests

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials, SpotifyOAuth
import os

import pandas as pd

import credentials

os.environ["SPOTIPY_CLIENT_ID"] = credentials.SPOTIPY_CLIENT_ID
os.environ["SPOTIPY_CLIENT_SECRET"] = credentials.SPOTIPY_CLIENT_SECRET
os.environ["SPOTIPY_REDIRECT_URI"] = credentials.SPOTIPY_REDIRECT_URI

# %%
spotify = spotipy.Spotify(client_credentials_manager=SpotifyClientCredentials())

# %%
scope = "playlist-read-private"

spotify = spotipy.Spotify(client_credentials_manager=SpotifyOAuth(scope=scope))

# %%
from src.worker.scraper import DiscoverEnhancer

# %load_ext autoreload
# %autoreload 2

# %%
enhancer = DiscoverEnhancer()

# %%
[f"{track['track']['name']}" for track in enhancer.get_discover_tracks()]
# Out:
# ['Lungs',
#  'Synphonic',
#  'The Leopard - Extrawelt Remix',
#  'Shadow Dance',
#  'Odium',
#  'All I See',
#  'Fidale',
#  'Mood - Dole & Kom Remix',
#  'Coming Back - Re.You Remix',
#  'Smoke - Niconé Remix',
#  'Back to Love - Hannes Bieger Remix',
#  'Louna - Sainte Vie Remix',
#  'Erational - Chloé Caillet Remix',
#  'Need U',
#  'Forevermore',
#  'Scorpion - Original Mix',
#  'The Solent',
#  'Feiern - Original Mix',
#  'Vacio',
#  'Moda',
#  'Valery',
#  '1k',
#  'Blinding Lights - Joris Voorn Remix',
#  'Endorphine',
#  'Kicking & Cooking',
#  'Weakness Pays',
#  'Hope',
#  'Sleep Paralysis',
#  'Grandma',
#  'Lockdown']

# %%
res = spotify.current_user()
print(res)
# Out:
# {'display_name': 'Nacho Maiz', 'external_urls': {'spotify': 'https://open.spotify.com/user/nachomaiz'}, 'followers': {'href': None, 'total': 84}, 'href': 'https://api.spotify.com/v1/users/nachomaiz', 'id': 'nachomaiz', 'images': [{'height': None, 'url': 'https://i.scdn.co/image/ab6775700000ee85dde96fc0bb8104ecf02f19b6', 'width': None}], 'type': 'user', 'uri': 'spotify:user:nachomaiz'}

# %%
res: dict[str,str] = spotify.current_user_playlists()

# %%
from typing import Any

discover: dict[str, Any] = spotify.playlist("3On7sjGzmFynhsCPKMEYg0")
discover
# Out:
# {'collaborative': False,
#  'description': '',
#  'external_urls': {'spotify': 'https://open.spotify.com/playlist/3On7sjGzmFynhsCPKMEYg0'},
#  'followers': {'href': None, 'total': 1},
#  'href': 'https://api.spotify.com/v1/playlists/3On7sjGzmFynhsCPKMEYg0?additional_types=track',
#  'id': '3On7sjGzmFynhsCPKMEYg0',
#  'images': [{'height': 640,
#    'url': 'https://mosaic.scdn.co/640/ab67616d0000b2735da49d1d4729b835612435deab67616d0000b273749c272987431691d094b607ab67616d0000b273f5c81e3f547afc68f4bb13d7ab67616d0000b273faab5a4042d8bd545447a127',
#    'width': 640},
#   {'height': 300,
#    'url': 'https://mosaic.scdn.co/300/ab67616d0000b2735da49d1d4729b835612435deab67616d0000b273749c272987431691d094b607ab67616d0000b273f5c81e3f547afc68f4bb13d7ab67616d0000b273faab5a4042d8bd545447a127',
#    'width': 300},
#   {'height': 60,
# ...

# %%
discover.keys()
# Out:
# dict_keys(['collaborative', 'description', 'external_urls', 'followers', 'href', 'id', 'images', 'name', 'owner', 'primary_color', 'public', 'snapshot_id', 'tracks', 'type', 'uri'])

# %%
discover['tracks']['items'][0]['track'].keys()
# Out:
# dict_keys(['album', 'artists', 'available_markets', 'disc_number', 'duration_ms', 'episode', 'explicit', 'external_ids', 'external_urls', 'href', 'id', 'is_local', 'name', 'popularity', 'preview_url', 'track', 'track_number', 'type', 'uri'])

# %%
from src.worker.scraper import Playlist

Playlist.from_response(discover)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\ignac\Documents\Python\spotify-discover-enhanced\Spotify Scratchwork.ipynb Cell 15' in <module>
#       <a href='vscode-notebook-cell:/c%3A/Users/ignac/Documents/Python/spotify-discover-enhanced/Spotify%20Scratchwork.ipynb#ch0000053?line=0'>1</a> from src.worker.scraper import Playlist
# ----> <a href='vscode-notebook-cell:/c%3A/Users/ignac/Documents/Python/spotify-discover-enhanced/Spotify%20Scratchwork.ipynb#ch0000053?line=2'>3</a> Playlist.from_response(discover)
#
# File c:\Users\ignac\Documents\Python\spotify-discover-enhanced\src\worker\scraper.py:66, in Playlist.from_response(cls, response)
#      <a href='file:///c%3A/Users/ignac/Documents/Python/spotify-discover-enhanced/src/worker/scraper.py?line=63'>64</a> res = {} | response
# ...

# %%
spotify.audi

# %%
discover
# Out:
# {'collaborative': False,
#  'description': '',
#  'external_urls': {'spotify': 'https://open.spotify.com/playlist/3On7sjGzmFynhsCPKMEYg0'},
#  'followers': {'href': None, 'total': 1},
#  'href': 'https://api.spotify.com/v1/playlists/3On7sjGzmFynhsCPKMEYg0?additional_types=track',
#  'id': '3On7sjGzmFynhsCPKMEYg0',
#  'images': [{'height': 640,
#    'url': 'https://mosaic.scdn.co/640/ab67616d0000b2735da49d1d4729b835612435deab67616d0000b273749c272987431691d094b607ab67616d0000b273f5c81e3f547afc68f4bb13d7ab67616d0000b273faab5a4042d8bd545447a127',
#    'width': 640},
#   {'height': 300,
#    'url': 'https://mosaic.scdn.co/300/ab67616d0000b2735da49d1d4729b835612435deab67616d0000b273749c272987431691d094b607ab67616d0000b273f5c81e3f547afc68f4bb13d7ab67616d0000b273faab5a4042d8bd545447a127',
#    'width': 300},
#   {'height': 60,
# ...

# %%
discover['tracks']['items'][0]['track'].keys()
# Out:
# dict_keys(['album', 'artists', 'available_markets', 'disc_number', 'duration_ms', 'episode', 'explicit', 'external_ids', 'external_urls', 'href', 'id', 'is_local', 'name', 'popularity', 'preview_url', 'track', 'track_number', 'type', 'uri'])

# %%
discover['tracks']['items'][0]
# Out:
# {'added_at': '2021-01-12T19:32:30Z',
#  'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/nachomaiz'},
#   'href': 'https://api.spotify.com/v1/users/nachomaiz',
#   'id': 'nachomaiz',
#   'type': 'user',
#   'uri': 'spotify:user:nachomaiz'},
#  'is_local': False,
#  'primary_color': None,
#  'track': {'album': {'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4aS7S2ESEryZfhTWcSgLXk'},
#      'href': 'https://api.spotify.com/v1/artists/4aS7S2ESEryZfhTWcSgLXk',
#      'id': '4aS7S2ESEryZfhTWcSgLXk',
#      'name': 'Maxxi Soundsystem',
#      'type': 'artist',
#      'uri': 'spotify:artist:4aS7S2ESEryZfhTWcSgLXk'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
# ...

# %%
enhancer.discover.summary()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\ignac\Documents\Python\spotify-discover-enhanced\Spotify Scratchwork.ipynb Cell 19' in <module>
# ----> <a href='vscode-notebook-cell:/c%3A/Users/ignac/Documents/Python/spotify-discover-enhanced/Spotify%20Scratchwork.ipynb#ch0000060?line=0'>1</a> enhancer.discover.summary()
#
# AttributeError: 'DiscoverEnhancer' object has no attribute 'discover'

# %%
import json

with open('test/samples/playlist.json', 'w') as f:
    json.dump(discover, f)

# %%
import json

with open('test/samples/track.json', 'w') as f:
    json.dump(spotify.track("7KCfp7dg5VbQLBaiOthW6s"), f)

# %%
import json

with open('test/samples/audio_features.json', 'w') as f:
    json.dump(spotify.audio_features(["7KCfp7dg5VbQLBaiOthW6s"]), f)

# %%
spotify.track("7KCfp7dg5VbQLBaiOthW6s")
# Out:
# {'album': {'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4aS7S2ESEryZfhTWcSgLXk'},
#     'href': 'https://api.spotify.com/v1/artists/4aS7S2ESEryZfhTWcSgLXk',
#     'id': '4aS7S2ESEryZfhTWcSgLXk',
#     'name': 'Maxxi Soundsystem',
#     'type': 'artist',
#     'uri': 'spotify:artist:4aS7S2ESEryZfhTWcSgLXk'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AL',
#    'AM',
#    'AO',
#    'AR',
#    'AT',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BF',
#    'BG',
#    'BH',
#    'BI',
#    'BJ',
#    'BN',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BY',
#    'BZ',
#    'CA',
#    'CD',
#    'CG',
#    'CH',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CW',
#    'CY',
#    'CZ',
#    'DE',
#    'DJ',
#    'DK',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FJ',
#    'FM',
#    'FR',
#    'GA',
# ...

# %%
spotify.track("7KCfp7dg5VbQLBaiOthW6s").keys()
# Out:
# dict_keys(['album', 'artists', 'available_markets', 'disc_number', 'duration_ms', 'explicit', 'external_ids', 'external_urls', 'href', 'id', 'is_local', 'name', 'popularity', 'preview_url', 'track_number', 'type', 'uri'])

# %%
res = spotify.current_user_playlists()

# %%
res['items'][0]['tracks']
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/3On7sjGzmFynhsCPKMEYg0/tracks',
#  'total': 346}

# %%
res["items"][0]
# Out:
# {'collaborative': False,
#  'description': '',
#  'external_urls': {'spotify': 'https://open.spotify.com/playlist/3On7sjGzmFynhsCPKMEYg0'},
#  'href': 'https://api.spotify.com/v1/playlists/3On7sjGzmFynhsCPKMEYg0',
#  'id': '3On7sjGzmFynhsCPKMEYg0',
#  'images': [{'height': 640,
#    'url': 'https://mosaic.scdn.co/640/ab67616d0000b2735da49d1d4729b835612435deab67616d0000b273749c272987431691d094b607ab67616d0000b273f5c81e3f547afc68f4bb13d7ab67616d0000b273faab5a4042d8bd545447a127',
#    'width': 640},
#   {'height': 300,
#    'url': 'https://mosaic.scdn.co/300/ab67616d0000b2735da49d1d4729b835612435deab67616d0000b273749c272987431691d094b607ab67616d0000b273f5c81e3f547afc68f4bb13d7ab67616d0000b273faab5a4042d8bd545447a127',
#    'width': 300},
#   {'height': 60,
#    'url': 'https://mosaic.scdn.co/60/ab67616d0000b2735da49d1d4729b835612435deab67616d0000b273749c272987431691d094b607ab67616d0000b273f5c81e3f547afc68f4bb13d7ab67616d0000b273faab5a4042d8bd545447a127',
#    'width': 60}],
# ...

# %%
deep = spotify.playlist_tracks("3On7sjGzmFynhsCPKMEYg0")

# %%
deep['items'][0]
# Out:
# {'added_at': '2021-01-12T19:32:30Z',
#  'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/nachomaiz'},
#   'href': 'https://api.spotify.com/v1/users/nachomaiz',
#   'id': 'nachomaiz',
#   'type': 'user',
#   'uri': 'spotify:user:nachomaiz'},
#  'is_local': False,
#  'primary_color': None,
#  'track': {'album': {'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4aS7S2ESEryZfhTWcSgLXk'},
#      'href': 'https://api.spotify.com/v1/artists/4aS7S2ESEryZfhTWcSgLXk',
#      'id': '4aS7S2ESEryZfhTWcSgLXk',
#      'name': 'Maxxi Soundsystem',
#      'type': 'artist',
#      'uri': 'spotify:artist:4aS7S2ESEryZfhTWcSgLXk'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
# ...

# %%
deep["items"][2]['track'].keys()
# Out:
# dict_keys(['album', 'artists', 'available_markets', 'disc_number', 'duration_ms', 'episode', 'explicit', 'external_ids', 'external_urls', 'href', 'id', 'is_local', 'name', 'popularity', 'preview_url', 'track', 'track_number', 'type', 'uri'])

# %%
deep["items"][2]['track']['artists']
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2I4hRNCYkPKJQlkoEZKjYx'},
#   'href': 'https://api.spotify.com/v1/artists/2I4hRNCYkPKJQlkoEZKjYx',
#   'id': '2I4hRNCYkPKJQlkoEZKjYx',
#   'name': 'Monolink',
#   'type': 'artist',
#   'uri': 'spotify:artist:2I4hRNCYkPKJQlkoEZKjYx'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/3LHqODf1hGAgZ5LTw1Gf4C'},
#   'href': 'https://api.spotify.com/v1/artists/3LHqODf1hGAgZ5LTw1Gf4C',
#   'id': '3LHqODf1hGAgZ5LTw1Gf4C',
#   'name': 'Acid Pauli',
#   'type': 'artist',
#   'uri': 'spotify:artist:3LHqODf1hGAgZ5LTw1Gf4C'}]

# %%
import pprint

pprint.pp(res["items"])
# Out:
# [{'collaborative': False,
#   'description': '',
#   'external_urls': {'spotify': 'https://open.spotify.com/playlist/3On7sjGzmFynhsCPKMEYg0'},
#   'href': 'https://api.spotify.com/v1/playlists/3On7sjGzmFynhsCPKMEYg0',
#   'id': '3On7sjGzmFynhsCPKMEYg0',
#   'images': [{'height': 640,
#               'url': 'https://mosaic.scdn.co/640/ab67616d0000b2735da49d1d4729b835612435deab67616d0000b273749c272987431691d094b607ab67616d0000b273f5c81e3f547afc68f4bb13d7ab67616d0000b273faab5a4042d8bd545447a127',
#               'width': 640},
#              {'height': 300,
#               'url': 'https://mosaic.scdn.co/300/ab67616d0000b2735da49d1d4729b835612435deab67616d0000b273749c272987431691d094b607ab67616d0000b273f5c81e3f547afc68f4bb13d7ab67616d0000b273faab5a4042d8bd545447a127',
#               'width': 300},
#              {'height': 60,
# ...

# %%
for idx, item in enumerate(res["items"]):
    print(item["name"])
# Out:
# Deep
# lofi hip hop music - beats to relax/study to
# Your Time Capsule
# COWBOY BEBOP -カウボーイビバップ-
# Beats to think to
# Discover Weekly
# A Playlist by Dano
# Lush Lofi
# NY State of Mind - Working Title
# The Prose of Rhyming in Rap
# On the Rocks!
# Seattle Grunge
# C. Tangana
# My Shazam Tracks
# Hippity Hop
# Sounds of The City...Machines, Industry and More
# Starred
# Future Classic: By Day
# Deep House
# Brain Food
# Chill
# Liquid Dubstep and D&B
# Dubstep
# Drum & Bass
# Cool
# TRAP!
# Tech/Deep House
# Burn
# Electroswing
# Cool
# chill/tranks
# Cool
# Chill
# Drum & Bass
# Dubstep
# BestofTrap
# Electro
# Broker's 10-year Playlist
# Liquid Dubstep
# Excellent Electroswing v. 2
# Liked from Radio
# Eclectic Ethereal Electronica - Music First
# Electro Swing
# RAVE
# Drum & Bass
# Dubstep
# New Dubstep Session
# Progressive
# Reggae
# Tech House

# %%
for idx, item in enumerate(res["items"]):
    print(item["name"], item['id'])
# Out:
# Deep 3On7sjGzmFynhsCPKMEYg0
# lofi hip hop music - beats to relax/study to 0vvXsWCC9xrXsKd4FyS8kM
# Your Time Capsule 37i9dQZF1EuI8VwQVVRMoq
# COWBOY BEBOP -カウボーイビバップ- 37i9dQZF1DX2niMzbAczXW
# Beats to think to 37i9dQZF1DXa2SPUyWl8Y5
# Discover Weekly 37i9dQZEVXcPDFsxBJanXQ
# A Playlist by Dano 6mu9s0RoxIGwX9gCfnoJiq
# Lush Lofi 37i9dQZF1DXc8kgYqQLMfH
# NY State of Mind - Working Title 0mz3WiAjLtlFq4SlP0UiJb
# The Prose of Rhyming in Rap 5KpHR1UysAms2zssDHeSbZ
# On the Rocks! 7lmj0kdtorwtxkbOsVaXqE
# Seattle Grunge 118vZyUVFnaJkcPgxEkdd0
# C. Tangana 1nWTgmHqFTI3bswylaOB3d
# My Shazam Tracks 07VnTEfIh7p8X92vzYInPN
# Hippity Hop 5IrdAbiwoIgGToxipmYhs6
# Sounds of The City...Machines, Industry and More 0jYXwP7kbgOdyTJRXxInVI
# Starred 4MiiFQGbPMrNzxrhxi067t
# Future Classic: By Day 0C7BjpmM5lQ9M4JP6UWG7x
# Deep House 2creivvrxoEvjy8L9gWkML
# Brain Food 37i9dQZF1DWXLeA8Omikj7
# Chill 2wpLG1wMEkkyZCgc2hP8oN
# Liquid Dubstep and D&B 1KHzSn9DpYdvJN25PcAAoA
# Dubstep 5Hi70mjRRPEW8QM1yuSNOJ
# ...

# %%
discover = spotify.playlist_tracks("37i9dQZEVXcPDFsxBJanXQ")
discover['items']
# Out:
# [{'added_at': '2022-02-21T05:00:00Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/75urDDpUkt0jMdQgVx3XFV'},
#       'href': 'https://api.spotify.com/v1/artists/75urDDpUkt0jMdQgVx3XFV',
#       'id': '75urDDpUkt0jMdQgVx3XFV',
#       'name': 'Artche',
#       'type': 'artist',
#       'uri': 'spotify:artist:75urDDpUkt0jMdQgVx3XFV'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
# ...

# %%
discover
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\ignac\Documents\Python\spotify-discover-enhanced\Spotify Scratchwork.ipynb Cell 21' in <module>
# ----> <a href='vscode-notebook-cell:/c%3A/Users/ignac/Documents/Python/spotify-discover-enhanced/Spotify%20Scratchwork.ipynb#ch0000038?line=0'>1</a> discover
#
# NameError: name 'discover' is not defined

# %%
discover['items'][0]['track'].keys()
# Out:
# dict_keys(['album', 'artists', 'available_markets', 'disc_number', 'duration_ms', 'episode', 'explicit', 'external_ids', 'external_urls', 'href', 'id', 'is_local', 'name', 'popularity', 'preview_url', 'track', 'track_number', 'type', 'uri'])

# %%
discover.keys()
# Out:
# dict_keys(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'])

# %%
res['items']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\ignac\Documents\Python\spotify-discover-enhanced\Spotify Scratchwork.ipynb Cell 24' in <module>
# ----> <a href='vscode-notebook-cell:/c%3A/Users/ignac/Documents/Python/spotify-discover-enhanced/Spotify%20Scratchwork.ipynb#ch0000045?line=0'>1</a> res['items']
#
# NameError: name 'res' is not defined

# %%
for k, v in discover.items():
    print(k, str(v)[:15])
# Out:
# href https://api.spo
# items [{'added_at': '
# limit 100
# next None
# offset 0
# previous None
# total 30

# %%
ConnectionRefusedError
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\ignac\Documents\Python\spotify-discover-enhanced\Spotify Scratchwork.ipynb Cell 26' in <module>
# ----> <a href='vscode-notebook-cell:/c%3A/Users/ignac/Documents/Python/spotify-discover-enhanced/Spotify%20Scratchwork.ipynb#ch0000047?line=0'>1</a> res
#
# NameError: name 'res' is not defined

# %%
discover
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/37i9dQZEVXcPDFsxBJanXQ/tracks?offset=0&limit=100&additional_types=track',
#  'items': [{'added_at': '2022-02-21T05:00:00Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/75urDDpUkt0jMdQgVx3XFV'},
#        'href': 'https://api.spotify.com/v1/artists/75urDDpUkt0jMdQgVx3XFV',
#        'id': '75urDDpUkt0jMdQgVx3XFV',
#        'name': 'Artche',
#        'type': 'artist',
#        'uri': 'spotify:artist:75urDDpUkt0jMdQgVx3XFV'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
# ...

# %%
url = str(discover['href'])
url
# Out:
# 'https://api.spotify.com/v1/playlists/37i9dQZEVXcPDFsxBJanXQ/tracks?offset=0&limit=100&additional_types=track'

# %%
import re

re.findall(r"playlists\/(\w*)\/", url)
# Out:
# ['37i9dQZEVXcPDFsxBJanXQ']

# %%
discover['items'][0]['track']['artists'][0]['name']
# Out:
# 'Artche'

# %%
discover['tracks'][0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\ignac\Documents\Python\spotify-discover-enhanced\Spotify Scratchwork.ipynb Cell 35' in <module>
# ----> <a href='vscode-notebook-cell:/c%3A/Users/ignac/Documents/Python/spotify-discover-enhanced/Spotify%20Scratchwork.ipynb#ch0000052?line=0'>1</a> discover['tracks'][0]
#
# KeyError: 0

# %%
discover['items'][0]['track']['name']
# Out:
# 'Lungs'

# %%
for i in discover['items']:
    print(i['name'])

# %%
pd.DataFrame(spotify.audio_features(['7ooSRbTulJUUtatq4pl80X','7ooSRbTulJUUtatq4pl80X'])).set_index('id')
# Out:
#                         danceability  energy  key  loudness  mode  \
# id
# 7ooSRbTulJUUtatq4pl80X         0.733   0.945    1    -9.938     1
# 7ooSRbTulJUUtatq4pl80X         0.733   0.945    1    -9.938     1
#
#                         speechiness  acousticness  instrumentalness  liveness  \
# id
# 7ooSRbTulJUUtatq4pl80X       0.0326        0.0156             0.903     0.101
# 7ooSRbTulJUUtatq4pl80X       0.0326        0.0156             0.903     0.101
#
#                         valence    tempo            type  \
# id
# 7ooSRbTulJUUtatq4pl80X    0.332  124.998  audio_features
# 7ooSRbTulJUUtatq4pl80X    0.332  124.998  audio_features
#
#                                                          uri  \
# id
# 7ooSRbTulJUUtatq4pl80X  spotify:track:7ooSRbTulJUUtatq4pl80X
# 7ooSRbTulJUUtatq4pl80X  spotify:track:7ooSRbTulJUUtatq4pl80X
#
#                                                                track_href  \
# id
# ...

# %%
from src.worker.scraper import DiscoverEnhancer

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
enhancer = DiscoverEnhancer()

# %%
enhancer.discover.summary().join(enhancer.discover.audio_features(enhancer.spotify))
# Out:
#                                                        Name  \
# 7ooSRbTulJUUtatq4pl80X                                Lungs
# 71NOKuKaMW49PnrIpHuqw1                            Synphonic
# 0CDSoT76AJ5DvjE5L16GBP        The Leopard - Extrawelt Remix
# 0TfG7h49ahceGMr6jAupxY                         Shadow Dance
# 4suC1hINTUwtEjbGDgeKzi                                Odium
# 18weulVGrDukxgOaUlnQJO                            All I See
# 7J0DIlnGW8C0IW1Gso1BDV                               Fidale
# 3ErdXxidIsTKoecR0OJkhN              Mood - Dole & Kom Remix
# 07ikk7X8EDJJk9T8H3XN8e           Coming Back - Re.You Remix
# 71Kq43qAOHuA5Nv8FSpyqX                 Smoke - Niconé Remix
# 3da6WLz3UL5OM2do5WaJ16   Back to Love - Hannes Bieger Remix
# 1CASwEFUqlnkwzu0bS1n5I             Louna - Sainte Vie Remix
# 3lQdX0eMRzprxMzNYVAfDJ      Erational - Chloé Caillet Remix
# 5YNzitqLw6SAPLEPjgnr4m                               Need U
# 1TdyHtal45B6qjbIG1IQfO                          Forevermore
# ...

# %%
pd.DataFrame(
            [
                enhancer.discover.track_names,
                enhancer.discover.track_artists,
                enhancer.discover.track_albums,
                enhancer.discover.track_duration,
            ],
        ).T.rename(index = dict(enumerate(enhancer.discover.track_uids)), columns = dict(enumerate(["Name", "Artists", "Album", "Duration"])))
# Out:
#                                                        Name  \
# 7ooSRbTulJUUtatq4pl80X                                Lungs
# 71NOKuKaMW49PnrIpHuqw1                            Synphonic
# 0CDSoT76AJ5DvjE5L16GBP        The Leopard - Extrawelt Remix
# 0TfG7h49ahceGMr6jAupxY                         Shadow Dance
# 4suC1hINTUwtEjbGDgeKzi                                Odium
# 18weulVGrDukxgOaUlnQJO                            All I See
# 7J0DIlnGW8C0IW1Gso1BDV                               Fidale
# 3ErdXxidIsTKoecR0OJkhN              Mood - Dole & Kom Remix
# 07ikk7X8EDJJk9T8H3XN8e           Coming Back - Re.You Remix
# 71Kq43qAOHuA5Nv8FSpyqX                 Smoke - Niconé Remix
# 3da6WLz3UL5OM2do5WaJ16   Back to Love - Hannes Bieger Remix
# 1CASwEFUqlnkwzu0bS1n5I             Louna - Sainte Vie Remix
# 3lQdX0eMRzprxMzNYVAfDJ      Erational - Chloé Caillet Remix
# 5YNzitqLw6SAPLEPjgnr4m                               Need U
# 1TdyHtal45B6qjbIG1IQfO                          Forevermore
# ...
